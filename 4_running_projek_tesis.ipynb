# %% [markdown]
# <a href="https://colab.research.google.com/github/sayyidul/mental_health_prediction/blob/main/4_running_projek_tesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install library yang dibutuhkan
# !pip install streamlit pyngrok xgboost -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 21.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 29.5 MB/s eta 0:00:00

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Copy file ke direktori Colab
# !cp "/content/drive/MyDrive/Prediksi Kesehatan Mental Apps/app_mental_health_1.py" .
# !cp "/content/drive/MyDrive/Prediksi Kesehatan Mental Apps/mental_health_selected5.csv" .
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pyngrok import ngrok

# Ganti dengan token ngrok kamu
ngrok.set_auth_token("3DekpbTCWVaVv8vhaO0UiYTiFoi_2JEQVYDUz8iS26wgFUQo7")

# Jalankan Streamlit di background
# !streamlit run app_mental_health_1.py &>/content/logs.txt &

# %%
import time
from pyngrok import ngrok

time.sleep(5)

# Kill any existing ngrok tunnels
ngrok.kill()

# Buat tunnel publik
public_url = ngrok.connect(8501)
print("🚀 Aplikasi bisa diakses di:", public_url)
# Out:
# 🚀 Aplikasi bisa diakses di: NgrokTunnel: "https://wool-trump-skipper.ngrok-free.dev" -> "http://localhost:8501"
